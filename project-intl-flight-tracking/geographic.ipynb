# %%
# IMPORT STATEMENTS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# CUSTOM FUNCTIONS
# from cleanSet.cleanGeographic import cleanGeographic

# %%
#IMPORT CRUDE PRICES BY REGION
price = pd.read_excel('data-sources/geographic/crude-price-by-region.xls')
price
# Out:
#           Date  U.S. Crude Oil First Purchase Price (Dollars per Barrel)  \
# 0   2010-01-15                                              72.87
# 1   2010-02-15                                              72.74
# 2   2010-03-15                                              75.77
# 3   2010-04-15                                              78.80
# 4   2010-05-15                                              70.91
# ..         ...                                                ...
# 119 2019-12-15                                              58.41
# 120 2020-01-15                                              56.86
# 121 2020-02-15                                              50.03
# 122 2020-03-15                                              31.80
# 123 2020-04-15                                              16.00
#
#      U.S. less Alaskan North Slope Crude Oil First Purchase Price (Dollars per Barrel)  \
# 0                                                73.16
# ...

# %%
# GATHER FLIGHT PRICES
ny = 'data-sources/geographic/ny.csv'
ny = cleanGeographic(ny)
ny.index
ny.shape
# Out:
# (42, 4)

# %%
# GATHER FLIGHT PRICES
ny2 = 'data-sources/geographic/ny2.csv'
ny2 = cleanGeographic(ny2)
ny2.groupby(ny2.index).first()
ny2.shape
# Out:
# (43, 4)

# %%
file = 'data-sources/geographic/ca.csv'
def cleanGeographic(file):
    df = pd.read_csv(file, skiprows=1)
    df.drop(df.tail(2).index, inplace=True)
    df['Period('] = df['Year'].astype(str) + ' - ' + df['Quarter'].astype(str).str[0]
    df.index = df['Period(']
    df = df.T


    df.drop(index=[df.index[0], df.index[1], df.index[2],
                  df.index[3], df.index[4],
                  df.index[6], df.index[8]], inplace=True)
    df = df.T
    df['Quarter'] = df.rename(columns={'Quarter': 'Quarter('}, inplace=True)
    df = df.T
    df['Location'] = df.index.str.split('(').str[0]
    df.drop(index='Quarter', inplace=True)
    
    df = df.T
    df.index = df.index.astype(str)
    for n in range(1, 5):
        df = df.drop(index=['1995 - {}'.format(n), '1996 - {}'.format(n), '1997 - {}'.format(n),
                        '1998 - {}'.format(n), '1999 - {}'.format(n),
                           '2000 - {}'.format(n), '2001 - {}'.format(n),
                           '2002 - {}'.format(n), '2003 - {}'.format(n),
                           '2004 - {}'.format(n), '2005 - {}'.format(n),
                           '2006 - {}'.format(n), '2007 - {}'.format(n),
                           '2008 - {}'.format(n), '2009 - {}'.format(n)])

    return df
ca = cleanGeographic(file)
ca
# Out:
#          Long Beach -  CA (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                  247.91
# 2010 - 2                                  285.78
# 2010 - 3                                   281.6
# 2010 - 4                                  276.13
# 2011 - 1                                  251.91
# 2011 - 2                                  282.31
# 2011 - 3                                  273.81
# 2011 - 4                                  261.91
# 2012 - 1                                  236.36
# 2012 - 2                                   274.2
# 2012 - 3                                  257.43
# 2012 - 4                                  262.12
# 2013 - 1                                  245.28
# 2013 - 2                                  262.49
# 2013 - 3                                  275.82
# 2013 - 4                                  275.32
# 2014 - 1                                  258.23
# 2014 - 2                                  271.98
# ...

# %%
all_sets = pd.merge(ny, ny2, left_index=True, right_index=True)
del all_sets['Period(_x']
del all_sets['Period(_y']
all_sets
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
# 2011 - 2                                         458.51
# 2011 - 3                                         442.86
# 2011 - 4                                         459.24
# 2012 - 1                                         454.84
# 2012 - 2                                         460.68
# 2012 - 3                                         432.71
# 2012 - 4                                         456.03
# 2013 - 1                                          461.3
# 2013 - 2                                         448.87
# 2013 - 3                                         462.25
# 2013 - 4                                         480.36
# ...

# %%
all_sets = pd.merge(all_sets, ca, left_index=True, right_index=True)
all_sets
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
# 2011 - 2                                         458.51
# 2011 - 3                                         442.86
# 2011 - 4                                         459.24
# 2012 - 1                                         454.84
# 2012 - 2                                         460.68
# 2012 - 3                                         432.71
# 2012 - 4                                         456.03
# 2013 - 1                                          461.3
# 2013 - 2                                         448.87
# 2013 - 3                                         462.25
# 2013 - 4                                         480.36
# ...

# %%
all_sets.drop(all_sets.columns[len(df.columns)-1], axis=1, inplace=True)

# %%
del all_sets['Period(']

# %%
all_sets = all_sets.T
all_sets.to_csv('trial.csv', sep=',', index=False)

# %%
all_sets.index
# Out:
# Index([ 'New York City - Greater (Inflation-Adjusted $)',
#              'New York JFK -  NY (Inflation-Adjusted $)',
#        'New York LaGuardia -  NY (Inflation-Adjusted $)',
#                    'Albany -  NY (Inflation-Adjusted $)',
#                   'Buffalo -  NY (Inflation-Adjusted $)',
#                 'Rochester -  NY (Inflation-Adjusted $)',
#                'Long Beach -  CA (Inflation-Adjusted $)',
#               'Los Angeles -  CA (Inflation-Adjusted $)',
#             'San Francisco -  CA (Inflation-Adjusted $)',
#                                                'Period(',
#                                                      243],
#       dtype='object')

# %%
all_sets = all_sets.T

# %%
all_sets
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
# 2011 - 2                                         458.51
# 2011 - 3                                         442.86
# 2011 - 4                                         459.24
# 2012 - 1                                         454.84
# 2012 - 2                                         460.68
# 2012 - 3                                         432.71
# 2012 - 4                                         456.03
# 2013 - 1                                          461.3
# 2013 - 2                                         448.87
# 2013 - 3                                         462.25
# 2013 - 4                                         480.36
# ...

# %%
all_sets = pd.read_csv('trial.csv')
all_sets
# Out:
#    2010 - 1  2010 - 2  2010 - 3  2010 - 4  2011 - 1  2011 - 2  2011 - 3  \
# 0    423.21    433.93    435.59     440.2    456.46    458.51    442.86
# 1    409.29    422.24    425.05    427.97    446.43    454.43    441.58
# 2    378.53     381.1    374.62    385.49    406.59    406.13    388.42
# 3    430.01    447.35    454.55    440.91    467.29    484.03    474.25
# 4    322.99    330.52    332.76    326.23    361.14    371.29    357.12
# 5    388.36    409.87    401.94    401.38    440.38    464.42    446.02
# 6    247.91    285.78     281.6    276.13    251.91    282.31    273.81
# 7    412.12    443.88     449.9    437.13    441.04    457.08    446.28
# 8    403.23    451.78    449.03    444.51    450.08    476.23     456.9
# 9  2010 - 1  2010 - 2  2010 - 3  2010 - 4  2011 - 1  2011 - 2  2011 - 3
#
#    2011 - 4  2012 - 1  2012 - 2  ...  2018 - 1  2018 - 2  2018 - 3  2018 - 4  \
# 0    459.24    454.84    460.68  ...     389.2    375.77    371.16    402.95
# ...

# %%
all_sets.to_excel('trialT.xlsx')

# %%
all_sets['Index'] = ' - '  + all_sets['Location']
all_sets.index = all_sets['Location'] 
all_sets
# Out:
#                            2010 - 1  2010 - 2  2010 - 3  2010 - 4  2011 - 1  \
# Location
# New York City - NY           423.21    433.93    435.59     440.2    456.46
# New York JFK -  NY           409.29    422.24    425.05    427.97    446.43
# New York LaGuardia -  NY     378.53     381.1    374.62    385.49    406.59
# Albany -  NY                 430.01    447.35    454.55    440.91    467.29
# Buffalo -  NY                322.99    330.52    332.76    326.23    361.14
# Rochester -  NY              388.36    409.87    401.94    401.38    440.38
# Long Beach -  CA             247.91    285.78     281.6    276.13    251.91
# Los Angeles -  CA            412.12    443.88     449.9    437.13    441.04
# San Francisco -  CA          403.23    451.78    449.03    444.51    450.08
# Period                     2010 - 1  2010 - 2  2010 - 3  2010 - 4  2011 - 1
#
#                            2011 - 2  2011 - 3  2011 - 4  2012 - 1  2012 - 2  \
# Location
# ...

# %%
all_sets = pd.read_csv('trial.csv')

# %%
all_sets
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
# 2011 - 2                                         458.51
# 2011 - 3                                         442.86
# 2011 - 4                                         459.24
# 2012 - 1                                         454.84
# 2012 - 2                                         460.68
# 2012 - 3                                         432.71
# 2012 - 4                                         456.03
# 2013 - 1                                          461.3
# 2013 - 2                                         448.87
# 2013 - 3                                         462.25
# 2013 - 4                                         480.36
# ...

# %%
file = 'data-sources/geographic/ca2.csv'
ca2 = cleanGeographic(file)
del ca2['Period(']
ca2
# Out:
#          Sacramento -  CA (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                  342.81
# 2010 - 2                                  373.55
# 2010 - 3                                  381.25
# 2010 - 4                                  372.09
# 2011 - 1                                  369.43
# 2011 - 2                                  407.82
# 2011 - 3                                  396.59
# 2011 - 4                                  393.52
# 2012 - 1                                  371.08
# 2012 - 2                                  411.58
# 2012 - 3                                  386.92
# 2012 - 4                                  393.19
# 2013 - 1                                  389.87
# 2013 - 2                                  418.35
# 2013 - 3                                  428.15
# 2013 - 4                                   409.4
# 2014 - 1                                  394.47
# 2014 - 2                                  426.57
# ...

# %%
all_sets = pd.merge(all_sets, ca2, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/fl.csv'
fl = cleanGeographic(file)
del fl['Period(']
fl.head()
# Out:
#          Ft  Lauderdale -  FL (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                       297.6
# 2010 - 2                                      295.47
# 2010 - 3                                       289.4
# 2010 - 4                                      288.08
# 2011 - 1                                      313.97
#
#          Miami -  FL (Inflation-Adjusted $) Tampa -  FL (Inflation-Adjusted $)
# Period(
# 2010 - 1                             409.96                             336.03
# 2010 - 2                             395.76                             346.23
# 2010 - 3                             388.21                             337.03
# 2010 - 4                             390.89                             328.09
# 2011 - 1                             434.35                             356.66

# %%
all_sets = pd.merge(all_sets, fl, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets.columns
# Out:
# Index(['New York City - Greater (Inflation-Adjusted $)',
#        'New York JFK -  NY (Inflation-Adjusted $)',
#        'New York LaGuardia -  NY (Inflation-Adjusted $)',
#        'Albany -  NY (Inflation-Adjusted $)',
#        'Buffalo -  NY (Inflation-Adjusted $)',
#        'Rochester -  NY (Inflation-Adjusted $)',
#        'Long Beach -  CA (Inflation-Adjusted $)',
#        'Los Angeles -  CA (Inflation-Adjusted $)',
#        'San Francisco -  CA (Inflation-Adjusted $)',
#        'Sacramento -  CA (Inflation-Adjusted $)',
#        'San Diego -  CA (Inflation-Adjusted $)',
#        'San Jose -  CA (Inflation-Adjusted $)',
#        'Ft  Lauderdale -  FL (Inflation-Adjusted $)_x',
#        'Miami -  FL (Inflation-Adjusted $)_x',
#        'Tampa -  FL (Inflation-Adjusted $)_x',
#        'Ft  Lauderdale -  FL (Inflation-Adjusted $)_y',
#        'Miami -  FL (Inflation-Adjusted $)_y',
#        'Tampa -  FL (Inflation-Adjusted $)_y'],
#       dtype='object')

# %%
del all_sets['Ft  Lauderdale -  FL (Inflation-Adjusted $)_x']
del all_sets['Miami -  FL (Inflation-Adjusted $)_x']
del all_sets['Tampa -  FL (Inflation-Adjusted $)_x']

# %%
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets.rename(columns={'Ft  Lauderdale -  FL (Inflation-Adjusted $)_y': 'Ft  Lauderdale -  FL (Inflation-Adjusted $)',
                        'Miami -  FL (Inflation-Adjusted $)_y': 'Miami -  FL (Inflation-Adjusted $)',
                        'Tampa -  FL (Inflation-Adjusted $)_y': 'Tampa -  FL (Inflation-Adjusted $)'})
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
# 2011 - 2                                         458.51
# 2011 - 3                                         442.86
# 2011 - 4                                         459.24
# 2012 - 1                                         454.84
# 2012 - 2                                         460.68
# 2012 - 3                                         432.71
# 2012 - 4                                         456.03
# 2013 - 1                                          461.3
# 2013 - 2                                         448.87
# 2013 - 3                                         462.25
# 2013 - 4                                         480.36
# ...

# %%
file = 'data-sources/geographic/pa.csv'
pa = cleanGeographic(file)
pa.head()
del pa['Period(']
pa.head()
# Out:
#          Harrisburg -  PA (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                  441.08
# 2010 - 2                                  452.24
# 2010 - 3                                  449.51
# 2010 - 4                                  461.19
# 2011 - 1                                  464.67
#
#          Philadelphia -  PA (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    401.21
# 2010 - 2                                    411.73
# 2010 - 3                                    408.69
# 2010 - 4                                    406.26
# 2011 - 1                                    426.44
#
#          Pittsburgh -  PA (Inflation-Adjusted $)
# Period(
# 2010 - 1                                  357.63
# 2010 - 2                                  373.22
# 2010 - 3                                  365.03
# 2010 - 4                                  355.81
# 2011 - 1                                  376.46

# %%
all_sets = pd.merge(all_sets, pa, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
del all_sets['Philadelphia -  PA (Inflation-Adjusted $)_x']
del all_sets['Harrisburg -  PA (Inflation-Adjusted $)_x']
del all_sets['Pittsburgh -  PA (Inflation-Adjusted $)_x']
all_sets
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
# 2011 - 2                                         458.51
# 2011 - 3                                         442.86
# 2011 - 4                                         459.24
# 2012 - 1                                         454.84
# 2012 - 2                                         460.68
# 2012 - 3                                         432.71
# 2012 - 4                                         456.03
# 2013 - 1                                          461.3
# 2013 - 2                                         448.87
# 2013 - 3                                         462.25
# 2013 - 4                                         480.36
# ...

# %%
del all_sets['Philadelphia -  PA (Inflation-Adjusted $)_y']
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/al-ar.csv'
al_ar = cleanGeographic(file)
al_ar.head()
del al_ar['Period(']
al_ar.head()
# Out:
#          Birmingham -  AL (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                  421.78
# 2010 - 2                                  420.81
# 2010 - 3                                     419
# 2010 - 4                                  405.34
# 2011 - 1                                  445.76
#
#          Huntsville -  AL (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                       0
# 2010 - 2                                       0
# 2010 - 3                                       0
# 2010 - 4                                       0
# 2011 - 1                                       0
#
#          Little Rock -  AR (Inflation-Adjusted $)
# Period(
# 2010 - 1                                   406.92
# 2010 - 2                                   429.77
# 2010 - 3                                    433.8
# 2010 - 4                                   417.36
# 2011 - 1                                   455.47

# %%
all_sets = pd.merge(all_sets, al_ar, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
del all_sets['Philadelphia -  PA (Inflation-Adjusted $)_x']
del all_sets['Harrisburg -  PA (Inflation-Adjusted $)_x']
del all_sets['Pittsburgh -  PA (Inflation-Adjusted $)_x']
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets.columns
# Out:
# Index(['New York City - Greater (Inflation-Adjusted $)',
#        'New York JFK -  NY (Inflation-Adjusted $)',
#        'New York LaGuardia -  NY (Inflation-Adjusted $)',
#        'Albany -  NY (Inflation-Adjusted $)',
#        'Buffalo -  NY (Inflation-Adjusted $)',
#        'Rochester -  NY (Inflation-Adjusted $)',
#        'Long Beach -  CA (Inflation-Adjusted $)',
#        'Los Angeles -  CA (Inflation-Adjusted $)',
#        'San Francisco -  CA (Inflation-Adjusted $)',
#        'Sacramento -  CA (Inflation-Adjusted $)',
#        'San Diego -  CA (Inflation-Adjusted $)',
#        'San Jose -  CA (Inflation-Adjusted $)',
#        'Ft  Lauderdale -  FL (Inflation-Adjusted $)',
#        'Miami -  FL (Inflation-Adjusted $)',
#        'Tampa -  FL (Inflation-Adjusted $)',
#        'Harrisburg -  PA (Inflation-Adjusted $)_x',
#        'Philadelphia -  PA (Inflation-Adjusted $)_x',
#        'Pittsburgh -  PA (Inflation-Adjusted $)_x',
# ...

# %%
file = 'data-sources/geographic/az-co.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
az_co.head()
# Out:
#          Denver -  CO (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                              345.72
# 2010 - 2                              348.31
# 2010 - 3                              353.15
# 2010 - 4                              353.13
# 2011 - 1                              368.08
#
#          Phoenix -  AZ (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                               353.49
# 2010 - 2                               368.76
# 2010 - 3                               366.44
# 2010 - 4                               361.24
# 2011 - 1                                374.1
#
#          Tucson -  AZ (Inflation-Adjusted $)
# Period(
# 2010 - 1                              380.88
# 2010 - 2                              405.08
# 2010 - 3                              396.54
# 2010 - 4                              403.43
# 2011 - 1                              403.08

# %%
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/ct-ga.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
az_co.head()
# Out:
#          Atlanta -  GA (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                               423.23
# 2010 - 2                               404.79
# 2010 - 3                               387.96
# 2010 - 4                                375.5
# 2011 - 1                               419.74
#
#          Hartford -  CT (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                443.75
# 2010 - 2                                456.08
# 2010 - 3                                447.38
# 2010 - 4                                427.38
# 2011 - 1                                 424.9
#
#          Savannah -  GA (Inflation-Adjusted $)
# Period(
# 2010 - 1                                517.98
# 2010 - 2                                498.29
# 2010 - 3                                486.72
# 2010 - 4                                490.22
# 2011 - 1                                535.13

# %%
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/i.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
az_co.head()
# Out:
#          Chicago O'Hare -  IL (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                      414.14
# 2010 - 2                                      421.72
# 2010 - 3                                      427.42
# 2010 - 4                                      421.34
# 2011 - 1                                      453.17
#
#          Des Moines -  IA (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                  461.48
# 2010 - 2                                  469.64
# 2010 - 3                                  465.24
# 2010 - 4                                  457.18
# 2011 - 1                                  480.65
#
#          Indianapolis -  IN (Inflation-Adjusted $)
# Period(
# 2010 - 1                                    355.65
# 2010 - 2                                    375.07
# 2010 - 3                                    371.15
# 2010 - 4                                     363.3
# 2011 - 1                                    387.38

# %%
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/k.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
az_co.head()
# Out:
#          Lexington -  KY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                      0
# 2010 - 2                                      0
# 2010 - 3                                      0
# 2010 - 4                                      0
# 2011 - 1                                      0
#
#          Louisville -  KY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                  406.07
# 2010 - 2                                  417.57
# 2010 - 3                                  414.58
# 2010 - 4                                  407.11
# 2011 - 1                                  432.89
#
#          Wichita -  KS (Inflation-Adjusted $)
# Period(
# 2010 - 1                               405.74
# 2010 - 2                               408.71
# 2010 - 3                               410.13
# 2010 - 4                               406.92
# 2011 - 1                               440.63

# %%
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/i-m.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
del all_sets['Lexington -  KY (Inflation-Adjusted $)_x']
del all_sets['Louisville -  KY (Inflation-Adjusted $)_x']
del all_sets[ 'Wichita -  KS (Inflation-Adjusted $)_x']
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets.columns
# Out:
# Index(['New York City - Greater (Inflation-Adjusted $)',
#        'New York JFK -  NY (Inflation-Adjusted $)',
#        'New York LaGuardia -  NY (Inflation-Adjusted $)',
#        'Albany -  NY (Inflation-Adjusted $)',
#        'Buffalo -  NY (Inflation-Adjusted $)',
#        'Rochester -  NY (Inflation-Adjusted $)',
#        'Long Beach -  CA (Inflation-Adjusted $)',
#        'Los Angeles -  CA (Inflation-Adjusted $)',
#        'San Francisco -  CA (Inflation-Adjusted $)',
#        'Sacramento -  CA (Inflation-Adjusted $)',
#        'San Diego -  CA (Inflation-Adjusted $)',
#        'San Jose -  CA (Inflation-Adjusted $)',
#        'Ft  Lauderdale -  FL (Inflation-Adjusted $)',
#        'Miami -  FL (Inflation-Adjusted $)',
#        'Tampa -  FL (Inflation-Adjusted $)',
#        'Harrisburg -  PA (Inflation-Adjusted $)_y',
#        'Philadelphia -  PA (Inflation-Adjusted $)_y',
#        'Pittsburgh -  PA (Inflation-Adjusted $)_y',
#        'Birmingham -  AL (Inflation-Adjusted $)',
# ...

# %%
file = 'data-sources/geographic/i-m.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/mi-mn.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/mi-mo.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
del all_sets['Detroit -  MI (Inflation-Adjusted $)_x']
del all_sets['Flint -  MI (Inflation-Adjusted $)_x']
del all_sets['Minneapolis/St  Paul -  MN (Inflation-Adjusted $)_x']
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets.columns
# Out:
# Index(['New York City - Greater (Inflation-Adjusted $)',
#        'New York JFK -  NY (Inflation-Adjusted $)',
#        'New York LaGuardia -  NY (Inflation-Adjusted $)',
#        'Albany -  NY (Inflation-Adjusted $)',
#        'Buffalo -  NY (Inflation-Adjusted $)',
#        'Rochester -  NY (Inflation-Adjusted $)',
#        'Long Beach -  CA (Inflation-Adjusted $)',
#        'Los Angeles -  CA (Inflation-Adjusted $)',
#        'San Francisco -  CA (Inflation-Adjusted $)',
#        'Sacramento -  CA (Inflation-Adjusted $)',
#        'San Diego -  CA (Inflation-Adjusted $)',
#        'San Jose -  CA (Inflation-Adjusted $)',
#        'Ft  Lauderdale -  FL (Inflation-Adjusted $)',
#        'Miami -  FL (Inflation-Adjusted $)',
#        'Tampa -  FL (Inflation-Adjusted $)',
#        'Harrisburg -  PA (Inflation-Adjusted $)_y',
#        'Philadelphia -  PA (Inflation-Adjusted $)_y',
#        'Pittsburgh -  PA (Inflation-Adjusted $)_y',
#        'Birmingham -  AL (Inflation-Adjusted $)',
# ...

# %%
file = 'data-sources/geographic/mi-mo.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/ne-nv.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/ni-nh.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/nm-nc.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
# file = 'data-sources/geographic/oh-nd.csv'
# az_co = cleanGeographic(file)
# az_co.head()
# del az_co['Period(']
# all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
# all_sets.head()

# %%
file = 'data-sources/geographic/ok-or.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
# file = 'data-sources/geographic/sd-tn.csv'
# az_co = cleanGeographic(file)
# az_co.head()
# del az_co['Period(']
# all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
# all_sets.head()

# %%
file = 'data-sources/geographic/tx.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/tx.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
del all_sets['Dallas-Fort Worth -  TX (Inflation-Adjusted $)_x']
del all_sets['San Antonio -  TX (Inflation-Adjusted $)_x']
del all_sets['Houston Bush -  TX (Inflation-Adjusted $)_x']
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets.columns
# Out:
# Index(['New York City - Greater (Inflation-Adjusted $)',
#        'New York JFK -  NY (Inflation-Adjusted $)',
#        'New York LaGuardia -  NY (Inflation-Adjusted $)',
#        'Albany -  NY (Inflation-Adjusted $)',
#        'Buffalo -  NY (Inflation-Adjusted $)',
#        'Rochester -  NY (Inflation-Adjusted $)',
#        'Long Beach -  CA (Inflation-Adjusted $)',
#        'Los Angeles -  CA (Inflation-Adjusted $)',
#        'San Francisco -  CA (Inflation-Adjusted $)',
#        'Sacramento -  CA (Inflation-Adjusted $)',
#        'San Diego -  CA (Inflation-Adjusted $)',
#        'San Jose -  CA (Inflation-Adjusted $)',
#        'Ft  Lauderdale -  FL (Inflation-Adjusted $)',
#        'Miami -  FL (Inflation-Adjusted $)',
#        'Tampa -  FL (Inflation-Adjusted $)',
#        'Harrisburg -  PA (Inflation-Adjusted $)_y',
#        'Philadelphia -  PA (Inflation-Adjusted $)_y',
#        'Pittsburgh -  PA (Inflation-Adjusted $)_y',
#        'Birmingham -  AL (Inflation-Adjusted $)',
# ...

# %%
file = 'data-sources/geographic/uv.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
file = 'data-sources/geographic/w.csv'
az_co = cleanGeographic(file)
az_co.head()
del az_co['Period(']
all_sets = pd.merge(all_sets, az_co, left_index=True, right_index=True)
all_sets.head()
# Out:
#          New York City - Greater (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                         423.21
# 2010 - 2                                         433.93
# 2010 - 3                                         435.59
# 2010 - 4                                          440.2
# 2011 - 1                                         456.46
#
#          New York JFK -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                    409.29
# 2010 - 2                                    422.24
# 2010 - 3                                    425.05
# 2010 - 4                                    427.97
# 2011 - 1                                    446.43
#
#          New York LaGuardia -  NY (Inflation-Adjusted $)  \
# Period(
# 2010 - 1                                          378.53
# 2010 - 2                                           381.1
# 2010 - 3                                          374.62
# ...

# %%
all_sets = all_sets.T

# %%
as_list = all_sets.index.tolist()
idx = as_list.index('New York City - Greater (Inflation-Adjusted $)')
as_list[idx] = 'New York City - NY (Inflation-Adjusted $)'
all_sets.index = as_list

# %%
all_sets
# Out:
# Period(                                         2010 - 1 2010 - 2 2010 - 3  \
# New York City - NY (Inflation-Adjusted $)         423.21   433.93   435.59
# New York JFK -  NY (Inflation-Adjusted $)         409.29   422.24   425.05
# New York LaGuardia -  NY (Inflation-Adjusted $)   378.53    381.1   374.62
# Albany -  NY (Inflation-Adjusted $)               430.01   447.35   454.55
# Buffalo -  NY (Inflation-Adjusted $)              322.99   330.52   332.76
# ...                                                  ...      ...      ...
# Richmond -  VA (Inflation-Adjusted $)             388.36   409.87   401.94
# Salt Lake City -  UT (Inflation-Adjusted $)       403.21   409.26   416.28
# Bellingham -  WA (Inflation-Adjusted $)           256.13   266.91   254.01
# Madison -  WI (Inflation-Adjusted $)              434.58   459.66   469.12
# Milwaukee -  WI (Inflation-Adjusted $)            298.06   311.74   310.71
#
# ...

# %%
# lst = all_sets.index.tolist()
# lst = [sentence.split(' - ') for sentence in lst]
# all_sets['State'] = [el[1][:3] for el in lst]

# %%
all_sets
# Out:
# Period(                                         2010 - 1 2010 - 2 2010 - 3  \
# New York City - NY (Inflation-Adjusted $)         423.21   433.93   435.59
# New York JFK -  NY (Inflation-Adjusted $)         409.29   422.24   425.05
# New York LaGuardia -  NY (Inflation-Adjusted $)   378.53    381.1   374.62
# Albany -  NY (Inflation-Adjusted $)               430.01   447.35   454.55
# Buffalo -  NY (Inflation-Adjusted $)              322.99   330.52   332.76
# ...                                                  ...      ...      ...
# Richmond -  VA (Inflation-Adjusted $)             388.36   409.87   401.94
# Salt Lake City -  UT (Inflation-Adjusted $)       403.21   409.26   416.28
# Bellingham -  WA (Inflation-Adjusted $)           256.13   266.91   254.01
# Madison -  WI (Inflation-Adjusted $)              434.58   459.66   469.12
# Milwaukee -  WI (Inflation-Adjusted $)            298.06   311.74   310.71
#
# ...

# %%
df.index
# Out:
# Index(['2018 - 1', '2020 - 1', '1995 - 3', '1995 - 4', '1996 - 1', '1996 - 2',
#        '1996 - 3', '1996 - 4', '1997 - 1', '1997 - 2',
#        ...
#        '2018 - 1', '2018 - 2', '2018 - 3', '2018 - 4', '2019 - 1', '2019 - 2',
#        '2019 - 3', '2019 - 4', '2020 - 1', 'Location'],
#       dtype='object', name='Period(', length=102)

# %%
all_sets.to_csv('cleaned-state-prices.csv', sep=',', index=False)

# %%
# CHANGE NY GREATER
